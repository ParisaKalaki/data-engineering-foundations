# %%
from kafka import KafkaConsumer
import json
from models import ride_from_row, Ride, ride_serializer

server = 'localhost:9092'
topic_name = 'rides'

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-console',
    value_deserializer=lambda b: Ride(**json.loads(b.decode("utf-8")))
)

record = next(consumer)

# %%
record.value
# Out:
# ConsumerRecord(topic='rides', partition=0, leader_epoch=1, offset=0, timestamp=1773221230159, timestamp_type=0, key=None, value={'PULocationID': 1, 'DOLocationID': 2, 'trip_distance': 10.5, 'total_amount': 25.0, 'tpep_pickup_datetime': 1640995200000}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=122, serialized_header_size=-1)
